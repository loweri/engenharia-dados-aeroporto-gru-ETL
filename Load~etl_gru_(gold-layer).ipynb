# %%
import datetime
import requests
import json # I find out that I need this to read the "return" from the weather API
from pyspark.sql.functions import (
    col,            
    lit,            
    when,           
    to_timestamp,   
    date_format,    
    hour,           
    dayofweek,      
    count,          
    sum             
)
from pyspark.sql.types import (
    StructType,
    StructField,
    StringType,
    IntegerType,
    DoubleType,
    TimestampType
)

print("Toolbox opened successfully 🧙‍♂️")
# Out:
# Toolbox opened successfully 🧙‍♂️

# %%
from pyspark.sql.functions import col, hour, count
df_silver = spark.read.table("personal_projects.gru_airport.silver_vra")
# What is the most common hour of the day for flights from GRU airport?
df_flux_hour = (
    df_silver
    # only dep. from GRU
    .filter(col("sigla_icao_origem") == "SBGR")
    #also here after the 1st run I had to create a new filter for the canceled flights
    .filter(col("partida_real").isNotNull())
    # creat a new column with the hour rounded
    .withColumn("hora_dia", hour(col("partida_real")))
    # group and count
    .groupBy("hora_dia")
    .agg(count("*").alias("total_voos"))
    # order to read by the highest
    .orderBy(col("total_voos").desc())
)

display(df_flux_hour)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>hora_dia</th><th>total_voos</th></tr></thead><tbody><tr><td>23</td><td>1017</td></tr><tr><td>9</td><td>1003</td></tr><tr><td>22</td><td>986</td></tr><tr><td>7</td><td>919</td></tr><tr><td>8</td><td>904</td></tr><tr><td>17</td><td>792</td></tr><tr><td>21</td><td>692</td></tr><tr><td>15</td><td>645</td></tr><tr><td>12</td><td>580</td></tr><tr><td>13</td><td>579</td></tr><tr><td>16</td><td>566</td></tr><tr><td>14</td><td>538</td></tr><tr><td>18</td><td>407</td></tr><tr><td>20</td><td>358</td></tr><tr><td>10</td><td>296</td></tr><tr><td>5</td><td>265</td></tr><tr><td>19</td><td>252</td></tr><tr><td>4</td><td>233</td></tr><tr><td>1</td><td>227</td></tr><tr><td>3</td><td>224</td></tr><tr><td>0</td><td>222</td></tr><tr><td>6</td><td>221</td></tr><tr><td>2</td><td>181</td></tr><tr><td>11</td><td>118</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
(df_flux_hour.write
  .format("delta")
  .mode("overwrite")
  .saveAsTable("personal_projects.gru_airport.gold_flux_schedule"))

print("Gold table saved successfully - Scheduled hour")
# Out:
# Gold table saved successfully - Scheduled hour

# %%
# Airlines Ranking by flights

df_ranking_airlines = (
    df_silver
    .filter(col("sigla_icao_origem") == "SBGR")
    .filter(col("partida_real").isNotNull())
    #groupby airlines
    .groupBy("empresa_aerea")
    .agg(count("*").alias("total_voos"))
    
    .orderBy(col("total_voos").desc())
)

display(df_ranking_airlines)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empresa_aerea</th><th>total_voos</th></tr></thead><tbody><tr><td>TAM LINHAS AÉREAS S.A.</td><td>5804</td></tr><tr><td>GOL LINHAS AÉREAS S.A. (EX- VRG LINHAS AÉREAS S.A.)</td><td>2962</td></tr><tr><td>AZUL LINHAS AÉREAS BRASILEIRAS S/A</td><td>846</td></tr><tr><td>LATAM AIRLINES GROUP (EX - LAN AIRLINES S/A)</td><td>197</td></tr><tr><td>COMPAÑIA PANAMEÑA DE AVIACION S.A. (COPA AIRLINES)</td><td>180</td></tr><tr><td>AMERICAN AIRLINES, INC.</td><td>154</td></tr><tr><td>AEROVIAS DEL CONTINENTE AMERICANO S.A. AVIANCA</td><td>137</td></tr><tr><td>UNITED AIRLINES, INC</td><td>123</td></tr><tr><td>PASSAREDO TRANSPORTES AÉREOS S.A.</td><td>115</td></tr><tr><td>SIDERAL LINHAS AÉREAS LTDA.</td><td>110</td></tr><tr><td>TURKISH AIRLINES INC</td><td>106</td></tr><tr><td>AEROLINEAS ARGENTINAS S/A</td><td>105</td></tr><tr><td>DELTA AIR LINES INC.</td><td>105</td></tr><tr><td>AIR CANADA</td><td>93</td></tr><tr><td>TAP - TRANSPORTES AÉREOS PORTUGUESES S/A</td><td>93</td></tr><tr><td>QATAR AIRWAYS GROUP</td><td>74</td></tr><tr><td>ETHIOPIAN AIRLINES GROUP</td><td>73</td></tr><tr><td>BOA BOLIVIANA DE AVIACIÓN</td><td>62</td></tr><tr><td>ITALIA TRANSPORTO AEREO S.P.A.</td><td>62</td></tr><tr><td>SOCIÉTÉ AIR FRANCE</td><td>61</td></tr><tr><td>TOTAL LINHAS AÉREAS S.A.</td><td>60</td></tr><tr><td>IBÉRIA LINEAS AEREAS DE ESPAÑA SOCIEDAD ANONIMA OPERADORA</td><td>58</td></tr><tr><td>TRANSPORTE AÉREOS DEL MERCOSUR S.A. (TAM MERCOSUR)</td><td>53</td></tr><tr><td>DEUTSCHE LUFTHANSA A.G.</td><td>45</td></tr><tr><td>BRITISH AIRWAYS PLC</td><td>44</td></tr><tr><td>SKY AIRLINE S.A.</td><td>41</td></tr><tr><td>EMIRATES</td><td>40</td></tr><tr><td>SWISS INTERNATIONAL AIR LINES LTD.</td><td>39</td></tr><tr><td>ABSA - AEROLINHAS BRASILEIRAS S.A.</td><td>36</td></tr><tr><td>ARAJET S.A.</td><td>32</td></tr><tr><td>AIR EUROPA LINEAS AEREAS SOCIEDAD ANONIMA</td><td>32</td></tr><tr><td>KLM CIA. REAL HOLANDESA DE AVIAÇÃO</td><td>31</td></tr><tr><td>AEROVÍAS DE MÉXICO S.A DE C.V - AEROMÉXICO</td><td>31</td></tr><tr><td>AIRES - AEROVÍAS DE INTEGRACÍON REGIONAL S.A.</td><td>31</td></tr><tr><td>SKY AIRLINE PERU S.A.C.</td><td>31</td></tr><tr><td>FB LÍNEAS AÉREAS S.A (FLYBONDI)</td><td>30</td></tr><tr><td>ATLAS AIR INC</td><td>28</td></tr><tr><td>MODERN TRANSPORTE AEREO DE CARGA S.A</td><td>25</td></tr><tr><td>TAAG LINHAS AÉREAS DE ANGOLA (ANGOLA AIRLINES)</td><td>18</td></tr><tr><td>SOUTH AFRICAN AIRWAYS STATE OWNED COMPANY (SOC) LIMITED</td><td>18</td></tr><tr><td>LAN CARGO S.A.</td><td>14</td></tr><tr><td>AIR CHINA</td><td>13</td></tr><tr><td>JETSMART AIRLINES SPA - CHILE</td><td>9</td></tr><tr><td>LÍNEA AÉREA CARGUEIRA DE COLOMBIA S.A - LANCO</td><td>3</td></tr><tr><td>NATIONAL AIRLINES</td><td>1</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
# second table - airline ranking

(df_ranking_airlines.write
  .format("delta")
  .mode("overwrite")
  .saveAsTable("personal_projects.gru_airport.gold_ranking_airlines"))

print("Ranking Airlines Table saved successfully")
# Out:
# Ranking Airlines Table saved successfully

# %%
# %sql
-- cancelled flights - ranking of the airlines:

CREATE OR REPLACE TABLE personal_projects.gru_airport.gold_cancelamentos AS
SELECT 
    empresa_aerea,
    COUNT(*) as total_cancelamentos
FROM 
    personal_projects.gru_airport.silver_vra
WHERE 
    situacao_voo = 'CANCELADO'
GROUP BY 
    empresa_aerea
ORDER BY 
    total_cancelamentos DESC;
SELECT * FROM personal_projects.gru_airport.gold_cancelamentos;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empresa_aerea</th><th>total_cancelamentos</th></tr></thead><tbody><tr><td>TAM LINHAS AÉREAS S.A.</td><td>169</td></tr><tr><td>ETHIOPIAN AIRLINES GROUP</td><td>151</td></tr><tr><td>SIDERAL LINHAS AÉREAS LTDA.</td><td>81</td></tr><tr><td>AZUL LINHAS AÉREAS BRASILEIRAS S/A</td><td>68</td></tr><tr><td>GOL LINHAS AÉREAS S.A. (EX- VRG LINHAS AÉREAS S.A.)</td><td>55</td></tr><tr><td>SKY AIRLINE S.A.</td><td>40</td></tr><tr><td>ATLAS AIR INC</td><td>36</td></tr><tr><td>COMPAGNIE NATIONALE ROYAL AIR MAROC</td><td>26</td></tr><tr><td>LATAM AIRLINES GROUP (EX - LAN AIRLINES S/A)</td><td>20</td></tr><tr><td>ITALIA TRANSPORTO AEREO S.P.A.</td><td>17</td></tr><tr><td>TAAG LINHAS AÉREAS DE ANGOLA (ANGOLA AIRLINES)</td><td>16</td></tr><tr><td>TOTAL LINHAS AÉREAS S.A.</td><td>15</td></tr><tr><td>BRITISH AIRWAYS PLC</td><td>14</td></tr><tr><td>ABSA - AEROLINHAS BRASILEIRAS S.A.</td><td>13</td></tr><tr><td>LAN CARGO S.A.</td><td>12</td></tr><tr><td>AMERICAN AIRLINES, INC.</td><td>10</td></tr><tr><td>QATAR AIRWAYS GROUP</td><td>10</td></tr><tr><td>FB LÍNEAS AÉREAS S.A (FLYBONDI)</td><td>9</td></tr><tr><td>IBÉRIA LINEAS AEREAS DE ESPAÑA SOCIEDAD ANONIMA OPERADORA</td><td>8</td></tr><tr><td>LÍNEA AÉREA CARGUEIRA DE COLOMBIA S.A - LANCO</td><td>6</td></tr><tr><td>PASSAREDO TRANSPORTES AÉREOS S.A.</td><td>6</td></tr><tr><td>UNITED AIRLINES, INC</td><td>6</td></tr><tr><td>AEROVIAS DEL CONTINENTE AMERICANO S.A. AVIANCA</td><td>3</td></tr><tr><td>DELTA AIR LINES INC.</td><td>3</td></tr><tr><td>TAP - TRANSPORTES AÉREOS PORTUGUESES S/A</td><td>2</td></tr><tr><td>SOCIÉTÉ AIR FRANCE</td><td>2</td></tr><tr><td>SWISS INTERNATIONAL AIR LINES LTD.</td><td>2</td></tr><tr><td>LATAM AIRLINES ECUADOR S.A.</td><td>1</td></tr><tr><td>AEROLINEAS ARGENTINAS S/A</td><td>1</td></tr><tr><td>SKY AIRLINE PERU S.A.C.</td><td>1</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
# %sql
-- average delay::
CREATE OR REPLACE TABLE personal_projects.gru_airport.gold_atrasos AS
SELECT 
    empresa_aerea,
    -- calculate the average delay in minutes
    ROUND(AVG((unix_timestamp(partida_real) - unix_timestamp(partida_prevista)) / 60), 2) as media_atraso_minutos,
    COUNT(*) as total_voos_considerados
FROM 
    personal_projects.gru_airport.silver_vra
WHERE 
    partida_real IS NOT NULL
GROUP BY 
    empresa_aerea
-- we are excluding arlines that has only a few flights (1 or 2)
HAVING 
    total_voos_considerados > 10
ORDER BY 
    media_atraso_minutos DESC;
SELECT * FROM personal_projects.gru_airport.gold_atrasos;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>empresa_aerea</th><th>media_atraso_minutos</th><th>total_voos_considerados</th></tr></thead><tbody><tr><td>ATLAS AIR INC</td><td>179.4</td><td>56</td></tr><tr><td>LAN CARGO S.A.</td><td>80.24</td><td>29</td></tr><tr><td>AMERICAN AIRLINES, INC.</td><td>68.62</td><td>309</td></tr><tr><td>SOUTH AFRICAN AIRWAYS STATE OWNED COMPANY (SOC) LIMITED</td><td>49.49</td><td>35</td></tr><tr><td>BOA BOLIVIANA DE AVIACIÓN</td><td>47.6</td><td>124</td></tr><tr><td>AIR EUROPA LINEAS AEREAS SOCIEDAD ANONIMA</td><td>45.16</td><td>64</td></tr><tr><td>AIR CHIN